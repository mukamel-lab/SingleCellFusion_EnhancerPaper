# %%
import cooler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing as mp
import h5py
import pickle
import seaborn as sns
import tqdm

from scipy import stats

from statsmodels.stats.multitest import multipletests

import sys
import itertools
import time
import datetime
import re

sys.path.insert(0, '/cndd/fangming/CEMBA/snmcseq_dev')
from __init__ import *
from __init__jupyterlab import * 
import snmcseq_utils

from enhancer_gene_hic_validation_utils import *

# %%
# default_colorbar_kws = DEFAULT_COLORBAR_KWS
today = datetime.date.today()

print(today)
# Out:
# 2020-12-26

# %%
chromosomes = ['chr'+str(i+1) for i in range(22)] + ['chrX']
celltypes = ['L2_3', 'L4', 'L5', 'L6', 
             'Pvalb', 'Sst', 'Vip', 'Ndnf']
resolution = 10000

# %% [markdown]
# # HiC-analysis - use only cell type-specific pairs
#
# Todo:
# - active gene needs to be active in that metacell!!!
#
# - assign 900 clusters into 8 cell types? (maybe not)
# - or how do we figure out the cluster assignment for each linked pair?

# %%
# gene expression profiles
f = '/cndd2/fangming/sphere_old/enhancers/scripts/data_organized/gene_rna_clsts.tsv'
gene_rna_clsts = pd.read_csv(f, sep='\t', index_col=0) #header=True, index=True)

# cluster annotation
f = '/cndd2/fangming/projects/scf_enhancers/enhancer_ethan38_200520/ref/annotations_order.tsv'
clst_annot = pd.read_csv(f, sep='\t').set_index('cluster')['annotation']

# merge cluster name
annot_rename_lookup = {
    'L2/3': "L2_3",
    'L4/5': "L4",
    'L6b': "L6",
    'Sncg': "Ndnf",
    'Lamp5': "Ndnf",
}

def rename_annot(x, annot_rename_lookup):
    """
    """
    if x in annot_rename_lookup.keys():
        return annot_rename_lookup[x]
    else:
        return x
    
clst_annot_broad = pd.Series([annot.split(' ')[0] for annot in clst_annot.values], 
                             index=clst_annot.index)
clst_annot_broad = clst_annot_broad.apply(lambda x: rename_annot(x, annot_rename_lookup))

print(clst_annot_broad.shape, 
      len(np.unique(clst_annot_broad.values)),
      np.unique(clst_annot_broad.values),
     )
# Out:
# (38,) 8 ['L2_3' 'L4' 'L5' 'L6' 'Ndnf' 'Pvalb' 'Sst' 'Vip']

# %%
# merge RNA profiles
_tmp = gene_rna_clsts.T
_tmp['annot'] = clst_annot_broad.loc[_tmp.index]
gene_rna_clsts_broad = _tmp.groupby('annot').median().T
gene_rna_clsts_broad_rank = gene_rna_clsts_broad.rank(pct=True, axis=1)
print(gene_rna_clsts_broad_rank.shape)
gene_rna_clsts_broad_rank.head()
# Out:
# (12095, 8)
# annot                L2_3     L4     L5     L6   Ndnf  Pvalb    Sst    Vip
# ENSMUSG00000000001  0.500  0.750  0.250  0.625  0.875  0.125  0.375  1.000
# ENSMUSG00000000056  0.125  0.750  0.875  0.500  0.625  1.000  0.250  0.375
# ENSMUSG00000000058  0.625  1.000  0.250  0.375  0.750  0.125  0.500  0.875
# ENSMUSG00000000078  0.250  1.000  0.625  0.750  0.125  0.500  0.875  0.375
# ENSMUSG00000000085  0.250  0.125  0.625  0.375  0.875  0.500  0.750  1.000

# %%
# update gene_rna_clsts_broad_rank

# gene-by-metacell matrix

# 1. read in gene by cell rna matrix
# 2. read in metacell profiles
# 3. group matrix into metacell
# 4. cpm normalization


### 1.

ti = time.time()
input_bundle_dirc = '/cndd2/fangming/projects/scf_enhancers/data/organized_cell_level/version_nov9'
bundle_fnames = (
    'cell_10x_cells_v3.txt',
    'gene_10x_cells_v3.txt',
    'mat_10x_cells_v3.npz',
)

# input_bundle
with snmcseq_utils.cd(input_bundle_dirc):
    bundle = []
    for fname in bundle_fnames:
        #  save all as pickle file
        with open(fname, "rb") as fh:
            item = pickle.load(fh)
        bundle.append(item)
        logging.info("{}_{}_{}".format(type(item), item.shape, fname))

(common_rna_cells, common_genes, X, 
) = bundle
print(common_rna_cells.shape, common_genes.shape, X.shape)

X = X.tocsc()

print(time.time()-ti)
# Out:
# (69727,) (31053,) (31053, 69727)
# 4.745639801025391

# %%
### 2.


# mod_x = '10x_cells_v3'
# input_name_tag = ''
# i_sub

# fname = 'clusterings_{}_{}_sub{}.tsv.gz'.format(mod_x, input_name_tag, i_sub)

# modx_clsts = pd.read_csv(fname, sep='\t', index_col=0)

# # get all clusterings
# def get_isub_clstfile(fname):
#     """Subsampling index
#     """
#     pattern = '_sub[0-9]+.tsv.gz' 
#     isub = int(re.findall(pattern, fname)[0][len("_sub"):-len('.tsv.gz')])
#     return isub 

# def get_knn_clstfile(fname):
#     """cross-modal knn
#     """
#     pattern = '_knn[0-9]+_' 
#     knn = int(re.findall(pattern, fname)[0][len("_knn"):-len('_')])
#     return knn 


def rename_col(col):
    """
    cluster_rx.xxxx -> cluster_rx.xx
    """
    if col.startswith('cluster_r'):
        r = float(col[len('cluster_r'):])
        newcol = 'cluster_r{:.1f}'.format(r)
        return newcol 
    else:
        return col
        
        
    


f_pattern = ("/cndd2/fangming/projects/miniatlas/results/"
             "clusterings_10x_cells_v3_mop_10x_cells_v3_snatac_gene_ka30_knn*_201206_sub*.tsv.gz"
             )
fnames = np.sort(glob.glob(f_pattern))
iterator_clsts = pd.DataFrame([{'i': get_isub_clstfile(fname),
                                'k': get_knn_clstfile(fname),
                                'fname': fname,
                              } for fname in fnames])
print(iterator_clsts.shape)

# res_clsts = []
modx_clsts = []
for idx, row in tqdm.tqdm(iterator_clsts.iterrows()):
    isub = row['i']
    knn = row['k']
    fname = row['fname']
    
    df = pd.read_csv(fname, index_col=0, sep='\t')
    modx_clsts.append(df)

modx_clsts = pd.concat(modx_clsts, axis=1)
modx_clsts.columns = [rename_col(col) for col in modx_clsts.columns]

print(modx_clsts.shape)
modx_clsts.head()

#     for col in df.columns:
#         r = float(col[len('cluster_r'):])
#         num_clst = len(df[col].unique())
#         res_clsts.append({
#             'k': knn,
#             'i': isub,
#             'r': r,
#             'num_clst': num_clst,
#         })
# #     break
# res_clsts = pd.DataFrame(res_clsts)

# print(res_clsts.shape)
# res_clsts.head()
# Out:
# 0it [00:00, ?it/s]
# (1, 3)
# 1it [00:00,  2.99it/s]
# (69727, 41)
#                                                    cluster_r1.0  cluster_r1.3  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             2             3
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             7             6
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             2             3
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             2             3
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             2             3
#
#                                                    cluster_r1.6  cluster_r2.0  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             3            16
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             6             2
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             3             6
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             3             6
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             3             6
#
#                                                    cluster_r2.5  cluster_r3.2  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            27             6
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             1            19
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            16             6
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            16             6
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            24            23
#
#                                                    cluster_r4.0  cluster_r5.0  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            24            25
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            12             5
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            25             6
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            25             6
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            10            13
#
#                                                    cluster_r6.3  cluster_r7.9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            15            44
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            40            75
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            14            36
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            14            73
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             8             9
#
#                                                          ...         \
# sample                                                   ...
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12        ...
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12        ...
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12        ...
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12        ...
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12        ...
#
#                                                    cluster_r1258.9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             3830
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             1932
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             8034
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             7202
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             8665
#
#                                                    cluster_r1584.9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             7579
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12              842
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             8828
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            11423
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            17495
#
#                                                    cluster_r1995.3  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            12280
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12              187
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             7495
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             7221
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            16382
#
#                                                    cluster_r2511.9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            15084
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12              482
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             9868
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            14838
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            14839
#
#                                                    cluster_r3162.3  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            12264
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12              164
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             6290
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            12266
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            12267
#
#                                                    cluster_r3981.1  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             9087
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             1127
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             9088
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             9089
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             9090
#
#                                                    cluster_r5011.9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             5752
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             1712
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             5753
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             5754
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             5755
#
#                                                    cluster_r6309.6  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             3679
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             6267
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             3680
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             3681
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             3682
#
#                                                    cluster_r7943.3  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             1922
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             1923
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             1924
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             1925
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             1926
#
#                                                    cluster_r10000.0
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12               896
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12               897
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12               898
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12               899
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12               900
#
# [5 rows x 41 columns]

# %%
# 2.5 select only 1 column - corresponds to the enh-gene linkages
r = 12.6
col = 'cluster_r{:.1f}'.format(r)
modx_clsts[col].head()
# Out:
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12     18
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12     78
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12     36
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12     84
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12    125
# Name: cluster_r12.6, dtype: int64

# %%
# 3. 

rna_metacell = pd.DataFrame([], 
                            index=common_genes,
                            columns=np.sort(modx_clsts[col].unique()))
for clst, df_sub in tqdm.tqdm(modx_clsts[[col]].groupby(col)):
    cell_ids = snmcseq_utils.get_index_from_array(common_rna_cells, df_sub.index.values)
    clst_rna_profiles = np.ravel(X[:,cell_ids].sum(axis=1))
    rna_metacell[clst] = clst_rna_profiles

# 4. logcpm
rna_metacell = snmcseq_utils.logcpm(rna_metacell_counts)

# 5. rank
rna_metacell = rna_metacell.rank(pct=True, axis=1)

print(rna_metacell.shape)
rna_metacell.head()

# now metacell - broad cluster correspondance? any need?
# Out:
# 100%|██████████| 130/130 [00:06<00:00, 19.30it/s]
# (31053, 130)
# (31053, 130)
#                          1         2         3         4         5    \
# ENSMUSG00000051951  2.270969  2.322870  2.287806  2.300954  2.307536
# ENSMUSG00000089699  1.603155  1.720358  1.799360  1.755488  1.788553
# ENSMUSG00000102343  0.270139  0.376115  0.284090  0.406129  0.147967
# ENSMUSG00000025900  0.671996  0.783921  0.791047  0.797447  0.719316
# ENSMUSG00000025902  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                          6         7         8         9         10   \
# ENSMUSG00000051951  2.364975  2.361899  2.321057  2.256968  2.299144
# ENSMUSG00000089699  1.934731  1.588212  1.799131  1.577846  1.628899
# ENSMUSG00000102343  0.366151  0.269107  0.220704  0.369270  0.186116
# ENSMUSG00000025900  0.715259  0.585093  0.657680  0.801490  0.823508
# ENSMUSG00000025902  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                       ...          121       122       123       124  \
# ENSMUSG00000051951    ...     2.409802  2.307507  2.307642  2.316399
# ENSMUSG00000089699    ...     1.779586  1.888804  1.670995  1.761399
# ENSMUSG00000102343    ...     0.000000  0.481148  0.168009  0.348258
# ENSMUSG00000025900    ...     0.628196  0.711189  0.689928  0.675326
# ENSMUSG00000025902    ...     0.000000  0.000000  0.000000  0.000000
#
#                          125       126       127       128       129       130
# ENSMUSG00000051951  2.297797  2.341602  2.289842  2.327091  2.373078  2.297033
# ENSMUSG00000089699  1.773008  1.661084  1.343789  1.539373  1.947541  1.753810
# ENSMUSG00000102343  0.411230  0.000000  0.385569  0.000000  0.378629  0.000000
# ENSMUSG00000025900  0.892692  0.554580  0.731521  0.510398  0.671048  0.604099
# ENSMUSG00000025902  0.000000  0.000000  0.300058  0.000000  0.000000  0.000000
#
# [5 rows x 130 columns]

# %%
min_matches = [0.8]

min_matches = np.arange(0.1, 1.00+0.05, 0.05)
# min_matches = [0.80]
print(min_matches)
# Out:
# [ 0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45  0.5   0.55  0.6   0.65
#   0.7   0.75  0.8   0.85  0.9   0.95  1.  ]

# %%
# enhancers lifted

for min_match in tqdm.tqdm(min_matches):
    print("**********{}".format(min_match))

    output_res_format = ('/cndd2/fangming/sphere_old/enhancers/scripts/results_new/'
                  'hic_contact_enrichment_metacell_liftover{:.2f}_celltypespec_{{}}_{{}}_{{}}_{{}}.pkl' #.format(int(100*active_th), celltype, resolution, today)
                  .format(min_match)
                 )

    f = '/cndd2/fangming/projects/scf_enhancers/enhancer_metacells_r100_n935/liftover/enhs_list_reformat_minmatch_{:.2f}_lifted.bed'.format(min_match)
    enh_list = pd.read_csv(f, sep='\t', header=None, names=['chr', 'start', 'end', 'enh_id']).astype({'chr': str, 
                                                                                                      'start': int,
                                                                                                      'end': int,
                                                                                                      'enh_id': int,
                                                                                                     })
    enh_list['center'] = (enh_list['start'] + enh_list['end'])/2

    # tss lifted
    f = '/cndd2/fangming/projects/scf_enhancers/enhancer_metacells_r100_n935/liftover/gencode.vM16.annotation_genes_tss_lifted.bed'
    tss_list = pd.read_csv(f, sep='\t', header=None, names=['chr', 'start', 'end', 'gid', 'gene_name'])
    tss_list['gid'] = tss_list['gid'].apply(lambda x: x.split('.')[0])

    # enh - tss linked list
    # orig significant pairs (enh_index and gid)
    input_format = '/cndd2/fangming/projects/scf_enhancers/enhancer_metacells_r100_n935/results_new/fig2_metacell_201221_r12.6_n130_'
    f = input_format + 'linked_pairs_mc.tsv'
    linked_pairs_mc = pd.read_csv(f, sep="\t")

    f = input_format + 'linked_pairs_atac.tsv'
    linked_pairs_atac = pd.read_csv(f, sep="\t")

    f = input_format + 'correlated_pairs_mc.tsv'
    correlated_pairs_mc = pd.read_csv(f, sep="\t")

    f = input_format + 'correlated_pairs_atac.tsv'
    correlated_pairs_atac = pd.read_csv(f, sep="\t")
    
    # subtract linked from correlated
    # genes can be divided into 4 non-overlapping quardrone: linked vs correlated; mc vs atac
    # below groups the 4 quardrone into 3 different groups
    correlated_pairs_mc = (pd.merge(linked_pairs_mc, correlated_pairs_mc, how='right', indicator=True)
                             .query('_merge=="right_only"')
                             .drop('_merge', axis=1)
                          )
    correlated_pairs_atac = (pd.merge(linked_pairs_atac, correlated_pairs_atac, how='right', indicator=True)
                             .query('_merge=="right_only"')
                             .drop('_merge', axis=1)
                          )
#     correlated_pairs_both = (pd.merge(linked_pairs_both, correlated_pairs_both, how='right', indicator=True)
#                              .query('_merge=="right_only"')
#                              .drop('_merge', axis=1)
#                           )
    linked_pairs_both = pd.merge(linked_pairs_mc, linked_pairs_atac, on=['gene', 'enh', 'dist'])
    correlated_pairs_both = pd.merge(correlated_pairs_mc, correlated_pairs_atac, on=['gene', 'enh', 'dist'])

    active_th = 0.5
    # distances
    distance_cutoff = 1e5
    distance_idx = np.arange(1, int(distance_cutoff/resolution)+1)
    distances = distance_idx * resolution

    for celltype in celltypes:
        print(celltype)

        contacts = [[] for i in np.arange(len(distances))]
        contacts_sig_pairs = collections.OrderedDict({
                'linked_mc': [[] for i in np.arange(len(distances))],
                'linked_atac': [[] for i in np.arange(len(distances))],
                'linked_both': [[] for i in np.arange(len(distances))],
                'correlated_mc': [[] for i in np.arange(len(distances))],
                'correlated_atac': [[] for i in np.arange(len(distances))],
                'correlated_both': [[] for i in np.arange(len(distances))],
            })

        for chromosome in chromosomes:
            print(celltype, resolution, chromosome)

            # read in the matrix 
            resource_string = (
                 '/cndd2/fangming/sphere_old/enhancers/data_m3c/{}_all_brain.txt_1kb_contacts.mcool'
                 '::/resolutions/{}'.format(celltype, resolution)
                 )
            c = cooler.Cooler(resource_string)
            mat_all = c.matrix(balance=True).fetch(chromosome)

            # all enhancers and tss on that chromosomes
            enhs = enh_list[enh_list['chr']==chromosome]
            tsss = tss_list[tss_list['chr']==chromosome]

            # only include the gene if it is actively expressed (>50% across cell types)
            active_genes = gene_rna_clsts_broad_rank[gene_rna_clsts_broad_rank[celltype]>active_th].index.values
            tsss = tsss[tsss['gid'].isin(active_genes)]
            
            

            # get paired bins
            paired_bin_tables = collections.OrderedDict({
                'linked_mc': enh_gene_id_to_binidx(linked_pairs_mc, tsss, enhs, resolution),
                'linked_atac': enh_gene_id_to_binidx(linked_pairs_atac, tsss, enhs, resolution),
                'linked_both': enh_gene_id_to_binidx(linked_pairs_both, tsss, enhs, resolution),
                'correlated_mc': enh_gene_id_to_binidx(correlated_pairs_mc, tsss, enhs, resolution),
                'correlated_atac': enh_gene_id_to_binidx(correlated_pairs_atac, tsss, enhs, resolution),
                'correlated_both': enh_gene_id_to_binidx(correlated_pairs_both, tsss, enhs, resolution),
            })
            track_names = list(paired_bin_tables.keys())

            # contact stats: distance bin by corr values in that bin
            (_contacts, _contacts_sig_pairs
            ) = get_contacts(mat_all, paired_bin_tables, resolution, distance_idx)

            # combine all chromosomes 
            for idx, dist in enumerate(distances):
                contacts[idx] += list(_contacts[idx])
                for key in _contacts_sig_pairs.keys():
                    contacts_sig_pairs[key][idx] += list(_contacts_sig_pairs[key][idx])
    #         break

        # stats
        contacts_mean = np.array([np.nanmean(val) for val in contacts])
        contacts_std = np.array([np.nanstd(val) for val in contacts])
        contacts_n = np.array([len(val) for val in contacts])

        contacts_sig_pairs_mean = collections.OrderedDict({
            key: np.zeros(len(distances)) 
            for key in contacts_sig_pairs.keys()
        })
        contacts_sig_pairs_std = contacts_sig_pairs_mean.copy()
        contacts_sig_pairs_n = contacts_sig_pairs_mean.copy()

        for key in contacts_sig_pairs.keys():
            contacts_sig_pairs_mean[key] = np.array([np.nanmean(val) 
                                                     for val in contacts_sig_pairs[key]])

            contacts_sig_pairs_std[key] = np.array([np.nanstd(val) 
                                                    for val in contacts_sig_pairs[key]])

            contacts_sig_pairs_n[key] = np.array([len(val) 
                                                  for val in contacts_sig_pairs[key]])


        # run and save results
        output_res = output_res_format.format(int(100*active_th), celltype, resolution, today)
        print(output_res)

        # save results
        # distances, contacts_mean, contacts_std ## these are numpy arrays 
        # contacts_sig_pairs_mean, contacts_sig_pairs_std ## these
        with open(output_res, 'wb') as fwh:
            pickle.dump((distances, 
                         contacts_mean, contacts_std, contacts_n,
                         contacts_sig_pairs_mean, 
                         contacts_sig_pairs_std,
                         contacts_sig_pairs_n,
                        ), fwh)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# **********0.1
# L2_3
# L2_3 10000 chr1
# 100%|██████████| 10/10 [00:00<00:00, 264.73it/s]
# L2_3 10000 chr2
# 100%|██████████| 10/10 [00:00<00:00, 284.43it/s]
# L2_3 10000 chr3
# 100%|██████████| 10/10 [00:00<00:00, 304.59it/s]
# L2_3 10000 chr4
# 100%|██████████| 10/10 [00:00<00:00, 319.94it/s]
# L2_3 10000 chr5
# 100%|██████████| 10/10 [00:00<00:00, 298.24it/s]
# L2_3 10000 chr6
# 100%|██████████| 10/10 [00:00<00:00, 329.31it/s]
# L2_3 10000 chr7
# 100%|██████████| 10/10 [00:00<00:00, 334.67it/s]
# L2_3 10000 chr8
# 100%|██████████| 10/10 [00:00<00:00, 346.53it/s]
# L2_3 10000 chr9
# 100%|██████████| 10/10 [00:00<00:00, 370.42it/s]
# L2_3 10000 chr10
# 100%|██████████| 10/10 [00:00<00:00, 339.44it/s]
# L2_3 10000 chr11
# 100%|██████████| 10/10 [00:00<00:00, 328.08it/s]
# L2_3 10000 chr12
# 100%|██████████| 10/10 [00:00<00:00, 326.90it/s]
# L2_3 10000 chr13
# 100%|██████████| 10/10 [00:00<00:00, 381.79it/s]
# L2_3 10000 chr14
# 100%|██████████| 10/10 [00:00<00:00, 362.32it/s]
# L2_3 10000 chr15
# 100%|██████████| 10/10 [00:00<00:00, 367.13it/s]
# L2_3 10000 chr16
# 100%|██████████| 10/10 [00:00<00:00, 378.94it/s]
# L2_3 10000 chr17
# 100%|██████████| 10/10 [00:00<00:00, 349.97it/s]
# L2_3 10000 chr18
# 100%|██████████| 10/10 [00:00<00:00, 398.39it/s]
# L2_3 10000 chr19
# 100%|██████████| 10/10 [00:00<00:00, 485.86it/s]
# L2_3 10000 chr20
# 100%|██████████| 10/10 [00:00<00:00, 388.10it/s]
# L2_3 10000 chr21
# 100%|██████████| 10/10 [00:00<00:00, 576.70it/s]
# L2_3 10000 chr22
# 100%|██████████| 10/10 [00:00<00:00, 381.52it/s]
# L2_3 10000 chrX
# 100%|██████████| 10/10 [00:00<00:00, 464.68it/s]
# /cndd2/fangming/sphere_old/enhancers/scripts/results_new/hic_contact_enrichment_metacell_liftover0.10_celltypespec_50_L2_3_10000_2020-12-22.pkl
# L4
# L4 10000 chr1
# 100%|██████████| 10/10 [00:00<00:00, 265.55it/s]
# L4 10000 chr2
# 100%|██████████| 10/10 [00:00<00:00, 297.71it/s]
# L4 10000 chr3
# 100%|██████████| 10/10 [00:00<00:00, 310.26it/s]
# L4 10000 chr4
# 100%|██████████| 10/10 [00:00<00:00, 142.53it/s]
# L4 10000 chr5
# 100%|██████████| 10/10 [00:00<00:00, 307.00it/s]
# L4 10000 chr6
# 100%|██████████| 10/10 [00:00<00:00, 325.24it/s]
# L4 10000 chr7
# 100%|██████████| 10/10 [00:00<00:00, 148.75it/s]
# L4 10000 chr8
# 100%|██████████| 10/10 [00:00<00:00, 349.82it/s]
# L4 10000 chr9
# 100%|██████████| 10/10 [00:00<00:00, 280.63it/s]
# L4 10000 chr10
# 100%|██████████| 10/10 [00:00<00:00, 348.52it/s]
# L4 10000 chr11
# 100%|██████████| 10/10 [00:00<00:00, 339.16it/s]
# L4 10000 chr12
# 100%|██████████| 10/10 [00:00<00:00, 327.02it/s]
# L4 10000 chr13
# 100%|██████████| 10/10 [00:00<00:00, 373.44it/s]
# L4 10000 chr14
# 100%|██████████| 10/10 [00:00<00:00, 373.63it/s]
# L4 10000 chr15
# 100%|██████████| 10/10 [00:00<00:00, 362.72it/s]
# L4 10000 chr16
# 100%|██████████| 10/10 [00:00<00:00, 387.80it/s]
# L4 10000 chr17
# 100%|██████████| 10/10 [00:00<00:00, 351.04it/s]
# L4 10000 chr18
# 100%|██████████| 10/10 [00:00<00:00, 387.75it/s]
# L4 10000 chr19
# 100%|██████████| 10/10 [00:00<00:00, 511.27it/s]
# L4 10000 chr20
# 100%|██████████| 10/10 [00:00<00:00, 393.34it/s]
# L4 10000 chr21
# 100%|██████████| 10/10 [00:00<00:00, 507.68it/s]
# L4 10000 chr22
# 100%|██████████| 10/10 [00:00<00:00,