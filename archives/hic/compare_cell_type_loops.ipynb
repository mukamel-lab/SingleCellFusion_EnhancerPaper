# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cell_type_loops = pd.read_excel('data/cell_type_loops.xlsx')

# %%
cell_type_loops.head()
# Out:
#    Table S3. Differential Interacting Regions              Unnamed: 1  \
# 0                                         NaN                     NaN
# 1                                 Interaction  edgeR_log2_fold_change
# 2     chr1:700000-750000 & chr1:750000-800000                 1.01661
# 3  chr1:950000-1000000 & chr1:1050000-1100000                 1.06329
# 4  chr1:950000-1000000 & chr1:1150000-1200000                 1.11911
#
#     Unnamed: 2     Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6  \
# 0          NaN            NaN           NaN           NaN           NaN
# 1    edgeR_FDR  L23_%_covered  L4_%_covered  L5_%_covered  L6_%_covered
# 2  0.000837705       0.141561     0.0763359      0.105556     0.0465116
# 3  1.32733e-07       0.150635      0.167939      0.105556     0.0930233
# 4  1.18158e-16        0.15971      0.175573      0.122222      0.104651
#
#        Unnamed: 7     Unnamed: 8       Unnamed: 9  ...   Unnamed: 21  \
# ...

# %%
import pickle
bins = pickle.load(open('data/annotated_bins.pkl', 'rb'))

# %%
bins.head()
# Out:
#   chrom  start   end  idx annotation
# 0  chr1      0  1000    0        NaN
# 1  chr1   1000  2000    1        NaN
# 2  chr1   2000  3000    2        NaN
# 3  chr1   3000  4000    3        NaN
# 4  chr1   4000  5000    4        NaN

# %% [markdown]
# # get all annotations in list format

# %%
bins['annoation'] = [[i] if type(i) != list else i for i in bins['annotation'].values]

# %% [markdown]
# # get bins overlapping differential regions

# %%
cell_type_loops.columns = cell_type_loops.loc[1].values

# %%
cell_type_loops.head()
# Out:
#                                   Interaction  edgeR_log2_fold_change  \
# 0                                         NaN                     NaN
# 1                                 Interaction  edgeR_log2_fold_change
# 2     chr1:700000-750000 & chr1:750000-800000                 1.01661
# 3  chr1:950000-1000000 & chr1:1050000-1100000                 1.06329
# 4  chr1:950000-1000000 & chr1:1150000-1200000                 1.11911
#
#      edgeR_FDR  L23_%_covered  L4_%_covered  L5_%_covered  L6_%_covered  \
# 0          NaN            NaN           NaN           NaN           NaN
# 1    edgeR_FDR  L23_%_covered  L4_%_covered  L5_%_covered  L6_%_covered
# 2  0.000837705       0.141561     0.0763359      0.105556     0.0465116
# 3  1.32733e-07       0.150635      0.167939      0.105556     0.0930233
# 4  1.18158e-16        0.15971      0.175573      0.122222      0.104651
#
#    Ndnf_%_covered  Sst_%_covered  Pvalb_%_covered  ...  Ndnf_average  \
# ...

# %% [markdown]
# ### get bins
