# %%
import sys
sys.path.insert(0, "/cndd/fangming/CEMBA/snmcseq_dev")
from multiprocessing import Pool,cpu_count
from functools import partial
from scipy import sparse
from scipy import stats
import pickle
import datetime
import argparse
import logging

import snmcseq_utils
from __init__ import *
from __init__jupyterlab import *

import CEMBA_clst_utils
import fbpca

# %%
# read in data
mod = '10x_cells_v3'

f_cell = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_neurons/{}_hvfeatures.cell'.format(mod)
f_gene = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_neurons/{}_hvfeatures.gene'.format(mod)
f_mat = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_neurons/{}_hvfeatures.npz'.format(mod)

gc_mat = snmcseq_utils.load_gc_matrix(f_gene, f_cell, f_mat)

print(gc_mat.data.shape, len(gc_mat.gene), len(gc_mat.cell))
# Out:
# (4694, 69727) 4694 69727

# %%
# config

start, end = -1, 2
resolutions = np.logspace(start, end, 10*(end-start)+1)
print(resolutions)

npc = 50
kforleiden = 30
# Out:
# [  0.1          0.12589254   0.15848932   0.19952623   0.25118864
#    0.31622777   0.39810717   0.50118723   0.63095734   0.79432823
#    1.           1.25892541   1.58489319   1.99526231   2.51188643
#    3.16227766   3.98107171   5.01187234   6.30957344   7.94328235
#   10.          12.58925412  15.84893192  19.95262315  25.11886432
#   31.6227766   39.81071706  50.11872336  63.09573445  79.43282347
#  100.        ]

# %%
# Louvain clustering for different resolutions

# X should be selected from highly variable genes and normalized
U, s, Vt = fbpca.pca(gc_mat.data.T.todense(), k=npc)
pcX = U.dot(np.diag(s))

res_clsts = CEMBA_clst_utils.clustering_routine_multiple_resolutions(
                    pcX, gc_mat.cell, kforleiden, 
                    seed=1, verbose=True,
                    resolutions=resolutions, metric='euclidean', option='plain', 
                    n_trees=10, search_k=-1, num_starts=None
                    )
print(res_clsts.shape)
res_clsts.head()
# Out:
# Time used to build kNN map 1.133622169494629
# Time used to get kNN 2.856416940689087
# Time spent on leiden clustering: 4.707091808319092
# Time spent on leiden clustering: 4.706509828567505
# Time spent on leiden clustering: 4.748021841049194
# Time spent on leiden clustering: 4.595489978790283
# Time spent on leiden clustering: 4.657553434371948
# Time spent on leiden clustering: 4.595909595489502
# Time spent on leiden clustering: 4.695640563964844
# Time spent on leiden clustering: 4.649114370346069
# Time spent on leiden clustering: 4.660450458526611
# Time spent on leiden clustering: 4.596345663070679
# Time spent on leiden clustering: 4.689942121505737
# Time spent on leiden clustering: 4.641426086425781
# Time spent on leiden clustering: 4.564808130264282
# Time spent on leiden clustering: 4.60343074798584
# Time spent on leiden clustering: 4.696444988250732
# Time spent on leiden clustering: 4.629019737243652
# Time spent on leiden clustering: 4.507610082626343
# Time spent on leiden clustering: 4.45438551902771
# Time spent on leiden clustering: 4.518430709838867
# Time spent on leiden clustering: 4.475775957107544
# Time spent on leiden clustering: 4.4433794021606445
# Time spent on leiden clustering: 4.4498450756073
# Time spent on leiden clustering: 4.439746856689453
# Time spent on leiden clustering: 4.521935224533081
# Time spent on leiden clustering: 4.42815637588501
# Time spent on leiden clustering: 4.380155563354492
# Time spent on leiden clustering: 4.466225624084473
# Time spent on leiden clustering: 4.437097549438477
# Time spent on leiden clustering: 4.423058748245239
# Time spent on leiden clustering: 4.500871181488037
# Time spent on leiden clustering: 4.464787721633911
# (69727, 31)
#                                                    cluster_r0.1  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12             1
#
#                                                    cluster_r0.12589254117941673  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                             4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                             1
#
#                                                    cluster_r0.15848931924611134  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                             4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                             1
#
#                                                    cluster_r0.19952623149688797  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                             4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                             1
#
#                                                    cluster_r0.251188643150958  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                           1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                           4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                           1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                           1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                           1
#
#                                                    cluster_r0.31622776601683794  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                             6
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                             1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                             1
#
#                                                    cluster_r0.3981071705534973  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                            1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                            6
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                            1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                            1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                            1
#
#                                                    cluster_r0.5011872336272724  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                            6
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                            3
#
#                                                    cluster_r0.6309573444801934  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                            7
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                            3
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                            3
#
#                                                    cluster_r0.7943282347242815  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                            2
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                            8
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                            2
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                            2
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                            2
#
#                                                    ...  \
# sample                                             ...
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12  ...
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12  ...
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12  ...
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12  ...
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12  ...
#
#                                                    cluster_r12.589254117941675  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                           79
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          117
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                           13
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                           43
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                          119
#
#                                                    cluster_r15.848931924611142  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                          105
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          117
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                           44
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                          121
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                          130
#
#                                                    cluster_r19.952623149688808  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                          104
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                           43
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                          177
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                           63
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                          115
#
#                                                    cluster_r25.11886431509582  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                         121
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          45
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                         189
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                          27
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                         125
#
#                                                    cluster_r31.622776601683793  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                          232
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          289
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                          216
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                           74
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                           84
#
#                                                    cluster_r39.810717055349734  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                          318
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          138
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                          178
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                          342
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                          182
#
#                                                    cluster_r50.11872336272725  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                         140
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                         138
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                         225
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                         344
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                         116
#
#                                                    cluster_r63.095734448019364  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                          401
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                          402
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                          449
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                          277
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                           55
#
#                                                    cluster_r79.43282347242821  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12                         287
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12                         415
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12                         523
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12                         243
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12                          24
#
#                                                    cluster_r100.0
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12             210
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12             368
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12             245
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12             114
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12              11
#
# [5 rows x 31 columns]

# %%
# get number of uniq clusters for each clustering
metadata = []
for col in res_clsts:
    num_clsts = len(res_clsts[col].unique())
    metadata.append({
        'name': col,
        'num_clsts': num_clsts,
    })
metadata = pd.DataFrame(metadata)

print(metadata.shape)
metadata.head()
# Out:
# (31, 2)
#                            name  num_clsts
# 0                  cluster_r0.1          8
# 1  cluster_r0.12589254117941673          8
# 2  cluster_r0.15848931924611134          8
# 3  cluster_r0.19952623149688797          8
# 4    cluster_r0.251188643150958          9

# %%
fig, ax = plt.subplots()
ax.plot(metadata['num_clsts'].values)
ax.set(**{'ylabel': 'Num clusters', 
          'xlabel': 'resolution (Leiden)', 
         })
ax.set_ylim(ymin=1)
ax.set_yscale('log')

print(metadata['num_clsts'].max())
plt.show()
# Out:
# 938

# %%
# group clusters with the same # of clusters

metadata_new = metadata.reset_index().groupby('num_clsts').first().copy().drop('index', axis=1)
metadata_new['name_new'] = ['cluster_n{}'.format(n) for n in metadata_new.index]

rename_dict = metadata_new[['name', 'name_new']].set_index('name')['name_new'].to_dict()
res_clsts_new = res_clsts[metadata_new['name']].rename(columns=rename_dict).copy()

# %%
metadata_new.head()
# Out:
#                                    name     name_new
# num_clsts
# 8                          cluster_r0.1   cluster_n8
# 9            cluster_r0.251188643150958   cluster_n9
# 12          cluster_r0.3981071705534973  cluster_n12
# 13         cluster_r0.31622776601683794  cluster_n13
# 14          cluster_r0.5011872336272724  cluster_n14

# %%
print(res_clsts_new.shape)
res_clsts_new.head()
# Out:
# (69727, 27)
#                                                    cluster_n8  cluster_n9  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           1           1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12           4           4
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           1           1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           1           1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12           1           1
#
#                                                    cluster_n12  cluster_n13  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            1            1
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            6            6
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            1            1
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            1            1
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            1            1
#
#                                                    cluster_n14  cluster_n16  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            3            2
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            6            8
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            3            2
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            3            2
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            3            2
#
#                                                    cluster_n17  cluster_n20  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12            2           13
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            8            8
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            2            3
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            2            3
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            2            3
#
#                                                    cluster_n24  cluster_n29  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           10            8
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            8            3
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           10            8
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           10            8
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12           15           17
#
#                                                    ...  cluster_n134  \
# sample                                             ...
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12  ...            79
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12  ...           117
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12  ...            13
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12  ...            43
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12  ...           119
#
#                                                    cluster_n164  cluster_n205  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           105           104
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12           117            43
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12            44           177
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           121            63
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12           130           115
#
#                                                    cluster_n256  cluster_n319  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           121           232
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12            45           289
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           189           216
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12            27            74
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12           125            84
#
#                                                    cluster_n398  cluster_n488  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           318           140
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12           138           138
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           178           225
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           342           344
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12           182           116
#
#                                                    cluster_n611  cluster_n749  \
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           401           287
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12           402           415
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           449           523
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           277           243
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            55            24
#
#                                                    cluster_n938
# sample
# 10x_cells_v3_AAACCCAAGCTTCATG-1L8TX_181211_01_G12           210
# 10x_cells_v3_AAACCCACACCAGCCA-1L8TX_181211_01_G12           368
# 10x_cells_v3_AAACGAACAACGATTC-1L8TX_181211_01_G12           245
# 10x_cells_v3_AAACGAATCTCGTGAA-1L8TX_181211_01_G12           114
# 10x_cells_v3_AAACGCTGTAGTCACT-1L8TX_181211_01_G12            11
#
# [5 rows x 27 columns]

# %%
# save results

name_tag = 'mop_10x_cells_v3_201120'
output_res = '/cndd2/fangming/projects/miniatlas/results/clusterings_{}.tsv.gz'.format(name_tag) 
output_meta = '/cndd2/fangming/projects/miniatlas/results/clusterings_meta_{}.tsv.gz'.format(name_tag) 

res_clsts_new.to_csv(output_res, sep='\t', na_rep='NA', header=True, index=True)
metadata_new.to_csv(output_meta, sep='\t', na_rep='NA', header=True, index=True)
