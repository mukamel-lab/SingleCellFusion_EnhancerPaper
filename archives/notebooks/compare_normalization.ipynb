# %%
import sys
import importlib
sys.path.insert(0, '/cndd/fangming/CEMBA/snmcseq_dev')
import snmcseq_utils
import CEMBA_clst_utils

from __init__jupyterlab import *

# %% [markdown]
# # CPM
#
# log10(CPM+1) why M?
# because 10^6 ~ library size

# %%
# compare different normalization

x = np.linspace(1e-6, 100, int(1e3))
y0 = np.log10(1+x)
y1 = np.log10(1+x*1e4)

fig, ax = plt.subplots()
# ax.plot(x, x, label='y=x')
ax.plot(x, y0, label='y=log10(x+1)')
ax.plot(x, y1, label='y=log10(x*1e4+1)')
# ax.set_xlim([0, 0.01])
# ax.set_ylim([0, 0.01])

ax.legend()
plt.show()
