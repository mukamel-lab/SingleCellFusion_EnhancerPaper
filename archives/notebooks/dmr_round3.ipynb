# %%
import sys
sys.path.insert(0, '/cndd/fangming/CEMBA/snmcseq_dev')

from __init__ import *
from snmcseq_utils import cd
from snmcseq_utils import create_logger
# from CEMBA_update_mysql import connect_sql

# %%
log = create_logger()
log.info("Hello")
# Out:
# 05/20/2020 04:57:34 PM Hello

# %%
# 
input_f = '/cndd2/fangming/projects/scf_enhancers/data/bulk/round3/mc/dmr/cgdmr_round3_rms_results_collapsed.tsv'
df = pd.read_table(input_f, index_col=['#chr', 'start', 'end'], dtype={'#chr': object})
print(df.shape)
df.head()
# Out:
# /cndd/fangming/venvs/conda_dobro/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /cndd/fangming/venvs/conda_dobro/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (1397463, 56)
#                       number_of_dms hypermethylated_samples  \
# #chr start   end
# chr1 3013472 3013579              3                     NaN
#      3021720 3021720              1                     NaN
#      3027398 3027514              2                     NaN
#      3033712 3033712              1                     NaN
#      3034471 3034646              2                     NaN
#
#                        hypomethylated_samples  methylation_level_1-1-1  \
# #chr start   end
# chr1 3013472 3013579  5-1-1,5-3-1,1-1-1,5-3-2                 0.561404
#      3021720 3021720                    5-3-1                 1.000000
#      3027398 3027514        4-2-1,4-2-2,5-3-1                 0.600000
#      3033712 3033712        6-2-1,6-4-1,8-3-1                 1.000000
#      3034471 3034646  4-2-1,6-2-1,6-4-1,6-5-3                 0.886364
#
#                       methylation_level_1-2-1  methylation_level_1-2-2  \
# #chr start   end
# chr1 3013472 3013579                 0.792453                 0.727273
#      3021720 3021720                 0.967742                 0.900000
#      3027398 3027514                 0.730159                 0.523810
#      3033712 3033712                 0.970588                 0.950000
#      3034471 3034646                 0.872340                 1.000000
#
#                       methylation_level_10-1-1  methylation_level_2-1-1  \
# #chr start   end
# chr1 3013472 3013579                       1.0                 0.849057
#      3021720 3021720                       NaN                 0.894737
#      3027398 3027514                       1.0                 0.673469
#      3033712 3033712                       NaN                 0.909091
#      3034471 3034646                       0.0                 0.926829
#
#                       methylation_level_2-1-2  methylation_level_2-2-1  ...  \
# #chr start   end                                                        ...
# chr1 3013472 3013579                 0.888889                 0.954545  ...
#      3021720 3021720                 0.958333                 0.846154  ...
#      3027398 3027514                 0.781818                 0.571429  ...
#      3033712 3033712                 0.960000                 1.000000  ...
#      3034471 3034646                 0.972222                 0.894737  ...
#
#                       methylation_level_7-1-2  methylation_level_7-2-1  \
# #chr start   end
# chr1 3013472 3013579                 1.000000                 1.000000
#      3021720 3021720                 1.000000                 1.000000
#      3027398 3027514                 0.733333                 0.666667
#      3033712 3033712                 1.000000                 1.000000
#      3034471 3034646                 1.000000                 1.000000
#
#                       methylation_level_7-2-2  methylation_level_8-1-1  \
# #chr start   end
# chr1 3013472 3013579                      1.0                      1.0
#      3021720 3021720                      1.0                      1.0
#      3027398 3027514                      1.0                      0.8
#      3033712 3033712                      1.0                      NaN
#      3034471 3034646                      1.0                      1.0
#
#                       methylation_level_8-1-2  methylation_level_8-2-1  \
# #chr start   end
# chr1 3013472 3013579                      1.0                 1.000000
#      3021720 3021720                      NaN                 0.857143
#      3027398 3027514                      1.0                 0.823529
#      3033712 3033712                      1.0                 1.000000
#      3034471 3034646                      NaN                 0.916667
#
#                       methylation_level_8-3-1  methylation_level_9-1-1  \
# #chr start   end
# chr1 3013472 3013579                      NaN                 0.666667
#      3021720 3021720                      1.0                 1.000000
#      3027398 3027514                      0.0                 1.000000
#      3033712 3033712                      0.0                 1.000000
#      3034471 3034646                      NaN                 1.000000
#
#                       methylation_level_9-2-1  methylation_level_9-2-2
# #chr start   end
# chr1 3013472 3013579                 0.400000                      0.0
#      3021720 3021720                 1.000000                      1.0
#      3027398 3027514                 0.714286                      1.0
#      3033712 3033712                 1.000000                      NaN
#      3034471 3034646                 1.000000                      1.0
#
# [5 rows x 56 columns]

# %%
print(df.shape)

df_hypo = df.loc[(df['number_of_dms']>=3) & (~df['hypomethylated_samples'].isnull()), 'hypomethylated_samples'].apply(lambda x: x.split(','))
df_hyper = df.loc[(df['number_of_dms']>=3) & (~df['hypermethylated_samples'].isnull()), 'hypermethylated_samples'].apply(lambda x: x.split(','))

print(df_hypo.shape)
print(df_hyper.shape)
# Out:
# (1397463, 56)
# (565104,)
# (478196,)

# %%
df_hypo.head()
# df_hypo_cluster = df_hypo.loc[
#         df_hypo.apply(lambda x: ('merged_mCG_{}_{}_{}'.format(cluster_type, i+1, ens) in x))]
# Out:
# #chr  start    end
# chr1  3013472  3013579                         [5-1-1, 5-3-1, 1-1-1, 5-3-2]
#       3093908  3094125           [1-2-2, 3-1-1, 5-2-1, 1-2-1, 4-1-1, 6-4-1]
#       3109231  3109390                                       [1-2-1, 1-2-2]
#       3112234  3112467    [6-2-1, 6-4-2, 6-6-1, 6-4-1, 5-3-1, 5-3-2, 5-1...
#       3113717  3114035    [2-1-1, 2-2-1, 6-2-1, 1-2-2, 3-1-1, 2-1-2, 2-3...
# Name: hypomethylated_samples, dtype: object

# %%
outdir = '/cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo'
if not os.path.isdir(outdir):
    os.makedirs(outdir)
    logging.info('Created directory {}'.format(outdir))
    
clsts = [i[len('methylation_level_'):] for i in df.filter(regex='^methylation_level_*').columns]
for clst in clsts:
    df_hypo_cluster = df_hypo[df_hypo.apply(lambda x: (clst in x))]
    output = os.path.join(outdir, 'dmr_{}.bed'.format(clst))
    df_hypo_cluster.to_csv(output, sep='\t', header=False, index=True, na_rep='NA')
    logging.info("Saved to {}".format(output))
    logging.info(df_hypo_cluster.shape)
# Out:
# 05/20/2020 05:01:56 PM Created directory /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo
# 05/20/2020 05:01:59 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_1-1-1.bed
# 05/20/2020 05:01:59 PM (220179,)
# 05/20/2020 05:02:02 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_1-2-1.bed
# 05/20/2020 05:02:02 PM (229060,)
# 05/20/2020 05:02:04 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_1-2-2.bed
# 05/20/2020 05:02:04 PM (183611,)
# 05/20/2020 05:02:05 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr
PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-2-1.bed
# 05/20/2020 05:02:52 PM (222425,)
# 05/20/2020 05:02:53 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-3-1.bed
# 05/20/2020 05:02:53 PM (46501,)
# 05/20/2020 05:02:54 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-3-2.bed
# 05/20/2020 05:02:54 PM (58802,)
# 05/20/2020 05:02:55 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-3-3.bed
# 05/20/2020 05:02:55 PM (58686,)
# 05/20/2020 05:02:57 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-4-1.bed
# 05/20/2020 05:02:57 PM (124772,)
# 05/20/2020 05:02:58 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-4-2.bed
# 05/20/2020 05:02:58 PM (72335,)
# 05/20/2020 05:02:59 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-5-1.bed
# 05/20/2020 05:02:59 PM (42782,)
# 05/20/2020 05:03:00 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-5-2.bed
# 05/20/2020 05:03:00 PM (50979,)
# 05/20/2020 05:03:01 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-5-3.bed
# 05/20/2020 05:03:01 PM (38026,)
# 05/20/2020 05:03:02 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_6-6-1.bed
# 05/20/2020 05:03:02 PM (24309,)
# 05/20/2020 05:03:02 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_7-1-1.bed
# 05/20/2020 05:03:02 PM (30966,)
# 05/20/2020 05:03:03 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_7-1-2.bed
# 05/20/2020 05:03:03 PM (38540,)
# 05/20/2020 05:03:04 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_7-2-1.bed
# 05/20/2020 05:03:04 PM (22511,)
# 05/20/2020 05:03:05 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_7-2-2.bed
# 05/20/2020 05:03:05 PM (26133,)
# 05/20/2020 05:03:06 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_8-1-1.bed
# 05/20/2020 05:03:06 PM (33405,)
# 05/20/2020 05:03:07 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_8-1-2.bed
# 05/20/2020 05:03:07 PM (8972,)
# 05/20/2020 05:03:08 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_8-2-1.bed
# 05/20/2020 05:03:08 PM (30941,)
# 05/20/2020 05:03:08 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_8-3-1.bed
# 05/20/2020 05:03:08 PM (5088,)
# 05/20/2020 05:03:09 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_9-1-1.bed
# 05/20/2020 05:03:09 PM (79043,)
# 05/20/2020 05:03:11 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_9-2-1.bed
# 05/20/2020 05:03:11 PM (58055,)
# 05/20/2020 05:03:11 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hypo/dmr_9-2-2.bed
# 05/20/2020 05:03:11 PM (26784,)

# %%
# hyper

outdir = '/cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper'
if not os.path.isdir(outdir):
    os.makedirs(outdir)
    logging.info('Created directory {}'.format(outdir))
    
clsts = [i[len('methylation_level_'):] for i in df.filter(regex='^methylation_level_*').columns]
for clst in clsts:
    df_hyper_cluster = df_hyper[df_hyper.apply(lambda x: (clst in x))]
    output = os.path.join(outdir, 'dmr_{}.bed'.format(clst))
    df_hyper_cluster.to_csv(output, sep='\t', header=False, index=True, na_rep='NA')
    logging.info("Saved to {}".format(output))
    logging.info(df_hyper_cluster.shape)
# Out:
# 05/20/2020 05:00:48 PM Created directory /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper
# 05/20/2020 05:00:49 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_1-1-1.bed
# 05/20/2020 05:00:49 PM (78138,)
# 05/20/2020 05:00:50 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_1-2-1.bed
# 05/20/2020 05:00:50 PM (66508,)
# 05/20/2020 05:00:51 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_1-2-2.bed
# 05/20/2020 05:00:51 PM (50899,)
# 05/20/2020 05:00:52 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr
PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-3-1.bed
# 05/20/2020 05:01:34 PM (46182,)
# 05/20/2020 05:01:35 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-3-2.bed
# 05/20/2020 05:01:35 PM (47822,)
# 05/20/2020 05:01:37 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-3-3.bed
# 05/20/2020 05:01:37 PM (88982,)
# 05/20/2020 05:01:38 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-4-1.bed
# 05/20/2020 05:01:38 PM (70475,)
# 05/20/2020 05:01:39 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-4-2.bed
# 05/20/2020 05:01:39 PM (77827,)
# 05/20/2020 05:01:40 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-5-1.bed
# 05/20/2020 05:01:40 PM (55542,)
# 05/20/2020 05:01:41 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-5-2.bed
# 05/20/2020 05:01:41 PM (46971,)
# 05/20/2020 05:01:42 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-5-3.bed
# 05/20/2020 05:01:42 PM (45346,)
# 05/20/2020 05:01:43 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_6-6-1.bed
# 05/20/2020 05:01:43 PM (4794,)
# 05/20/2020 05:01:45 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_7-1-1.bed
# 05/20/2020 05:01:45 PM (136307,)
# 05/20/2020 05:01:47 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_7-1-2.bed
# 05/20/2020 05:01:47 PM (165699,)
# 05/20/2020 05:01:49 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_7-2-1.bed
# 05/20/2020 05:01:49 PM (70393,)
# 05/20/2020 05:01:50 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_7-2-2.bed
# 05/20/2020 05:01:50 PM (83419,)
# 05/20/2020 05:01:51 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_8-1-1.bed
# 05/20/2020 05:01:51 PM (29276,)
# 05/20/2020 05:01:52 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_8-1-2.bed
# 05/20/2020 05:01:52 PM (6113,)
# 05/20/2020 05:01:53 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_8-2-1.bed
# 05/20/2020 05:01:53 PM (85520,)
# 05/20/2020 05:01:54 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_8-3-1.bed
# 05/20/2020 05:01:54 PM (3223,)
# 05/20/2020 05:01:54 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_9-1-1.bed
# 05/20/2020 05:01:54 PM (10472,)
# 05/20/2020 05:01:55 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_9-2-1.bed
# 05/20/2020 05:01:55 PM (9020,)
# 05/20/2020 05:01:56 PM Saved to /cndd2/fangming/projects/scf_enhancers/data/bulk/round3/dmr_hyper/dmr_9-2-2.bed
# 05/20/2020 05:01:56 PM (3060,)

# %% [markdown]
# # Not organized

# %%
with cd(os.path.join(PATH_ENSEMBLES, ens, 'dmr')):
    f = 'dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_rms_results_collapsed.tsv.DMR.bed'
    df_bed = pd.read_table(f, header=None, names=['chr', 'start', 'end', 'num_dms'])
print(df_bed.shape)
df_bed.head()
# Out:
# (1162175, 4)
#     chr    start      end  num_dms
# 0  chr1  3013472  3013473        1
# 1  chr1  3023074  3023075        1
# 2  chr1  3027397  3027398        1
# 3  chr1  3034471  3034472        1
# 4  chr1  3044312  3044403        3

# %%
df_out = df_bed[df_bed['num_dms']>=20]
with cd(os.path.join(PATH_ENSEMBLES, ens, 'dmr')):
    df_out.to_csv('dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_rms_results_collapsed_20dms.tsv.DMR.bed', 
                 sep='\t', na_rep='NA', header=False, index=False)
